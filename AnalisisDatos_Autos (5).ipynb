# %% [markdown]
# <img SRC="img01.png" />
#          <center><h1 Style="color:#0000FF">Analisis de Datos</h1></center>
#          <center><h5>Universidad Castro Carazo</h5></center>
#          <center><h6>2C- 2022</h6></center>
#          </br>
#          </br>

# %% [markdown]
# El siguiente trabajo es el primer paso para empezar con el analisis de datos por medio de python, anaconda y usando jupyter.
# Se usa conceptos como h6, h3 yh1 para los titulos.
# </br>
# <a href="https://archive.ics.uci.edu/ml/datasets.php">Fuente de datos para el analisis</a>

# %% [markdown]
# <h2 Style="color:#DC143C">1. Carga y estandarizacion de los set de datos</h2>
# <p>Que se hace en esta etapa?</p>
#
#
# <ol>
#     <li>Importar las librerias necesarias</li>
#     <li>Importar el o los set de datos</li>
#     <li>Revisar los encabezados de los dataframes</li>
#
# </ol>
#
# <h3 Style="color:#000080">1.1 Importar las librerias </h3>

# %%
import pandas as pd              #se usa para el manejo de dataframe.
import numpy as  np              #se usa para el manejo de estructura de datos
import matplotlib.pyplot as plt   # se usa para elmanejo de graficos

# %% [markdown]
# <h3 Style ="color:#000080">1.2 Importar el set de datos </h3>

# %%
cols= ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
"style", "wheels", "engine", "base", "length", "width", "heingt",
"curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
"compression", "horsepower", "peak", "City", "Higway", "price"]


df_1er_autos=pd.read_csv("autos.csv", names=cols)
df_2do_autos=pd.read_csv("Autos 1.csv", names=cols)

# %%
df_1er_autos.shape  # esto me permite conocer el tamaño del dataframe
# Out:
# (197, 26)

# %%
df_2do_autos.shape
# Out:
# (29, 26)

# %%
df_1er_autos.head(10)  # esto me permite visualizar la cantidad de columnas que deseo ver.
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2          ?         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1          ?         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0          ?         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# ...

# %%
df_1er_autos.tail(10) # esto me permite visualizar el numero de las ultimas columnas que yo desee ver
# Out:
#      symboling normalized        make    fuel aspiration doors        style  \
# 187          2         94  volkswagen  diesel      turbo  four        sedan
# 188          2         94  volkswagen     gas        std  four        sedan
# 189          3          ?  volkswagen     gas        std   two  convertible
# 190          3        256  volkswagen     gas        std   two    hatchback
# 191          0          ?  volkswagen     gas        std  four        sedan
# 192          0          ?  volkswagen  diesel      turbo  four        sedan
# 193          0          ?  volkswagen     gas        std  four        wagon
# 194         -2        103       volvo     gas        std  four        sedan
# 195         -1         74       volvo     gas        std  four        wagon
# 196         -2        103       volvo     gas        std  four        sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_1er_autos.describe() # esta funcion me describe mediante valores estadisticos como esta conformado mi conjunto de datos, el total,la media, el valor minimo, el vaalor maximo , percentil 25, 50,75.
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %% [markdown]
# <h3 Style ="color:##2F4F4F">1.3 Revisar encabezados de los set de datos </h3>

# %%
df_1er_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engine-size  197 non-null    int64
#  17  system       197 non-null    object
# ...

# %%
df_1er_autos.columns # traer columnas
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns # Revisar que esten en el mismo orden
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# <h3 Style ="color:##2F4F4F">1.4 Unir Arrchivos en un solo DataFrame </h3>

# %%
unionArchivos=[df_1er_autos, df_2do_autos]#Lista de DataFrames
dfAutos=pd.concat(unionArchivos)
dfAutos.shape  #226 datos, 26 columnas, se unen una vez se han revisado que los archivos no sean desiguales,estructura de listas igual o similiar.
# Out:
# (226, 26)

# %%
dfAutos.head(4)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
#
# [4 rows x 26 columns]

# %%
dftem = dfAutos.iloc[:,0:2]# first two columns of data frame with all rows, iloc para buscar columnas en especifico.

# %%
dftem.head(6)
# Out:
#    symboling normalized
# 0          3          ?
# 1          3          ?
# 2          1          ?
# 3          2        164
# 4          2        164
# 5          2          ?

# %%
dftemp = dfAutos.iloc[[0,3,6,24], [0,5,6]] #  1st, 4th,7th,25th row +1st 6th 7th columns

# %%
dftemp
# Out:
#     symboling doors        style
# 0           3   two  convertible
# 3           2  four        sedan
# 6           1  four        sedan
# 24          1  four    hatchback

# %%
df_Autos=dfAutos

# %%
df_Autos.shape
# Out:
# (226, 26)

# %% [markdown]
# <h2 Style="color:#DC143C">2. Manejo de Valores Faltantes o Perdidos </h2>
# <p>Que se hace en esta etapa?</p>
# <ol>
#     <li>Identificar como se muestran los valores faltantes y estandarizarlos </li>
#     <li>Contar la cantidad de valores NAN faltantes por variable(columna)</li>
#     <li>Analisis de imputacion (el promedio/ML) para el caso de los numericos </li>
#     <li>Analisis de imputacion (con el valor mas frecuente /ML) para el caso de los caracter </li>
#     <li>Eliminan filas o columnas con valores faltantes </li>
# </ol>
#
# <h3 Style="color:color:##2F4F4F">2.1 Identificar como se muestran los valores faltantes y estandarizarlos</h3>

# %%
df_Autos.head(2)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
#
# [2 rows x 26 columns]

# %%
df_Autos.replace("?",np.nan,inplace= True)

# %%
df_Autos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2        NaN         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1        NaN         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0        NaN         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# ...

# %% [markdown]
# <h3 Style="color:color:##2F4F4F">2.2 Contar valores faltantes por columna</h3>

# %%
valoresPerdidos=df_Autos.isnull()# si no se ha hecho el paso de poner NaN este paso no funciona

# %%
valoresPerdidos.head(5)# si no esta nulo me devuelve un falso
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# 1   False  False  ...        False   False  False   False        False
# 2   False  False  ...        False   False  False   False        False
# 3   False  False  ...        False   False  False   False        False
# 4   False  False  ...        False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# ...

# %%
for column in valoresPerdidos.columns.values.tolist():
    print(column)
    print(valoresPerdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engine-size
# False    226
# Name: engine-size, dtype: int64
#
# system
# ...

# %% [markdown]
# <h3 Style="color:color:##2F4F4F">2.3 Imputar datos numericos</h3>
# <img SRC="img02.png" />

# %%
avg_normalized=df_Autos["normalized"].astype("float").mean(axis=0)
print("la media del normalized: ", avg_normalized)
# Out:
# la media del normalized:  122.28333333333333

# %%
df_Autos["normalized"].replace(np.nan,122, inplace=True)
df_Autos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
#
# [3 rows x 26 columns]

# %% [markdown]
# <h3 Style="color:color:##2F4F4F">2.4 Imputar Datos Tipo Caracter</h3>

# %%
df_Autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
df_Autos["doors"].value_counts()
# Out:
# four    124
# two     100
# Name: doors, dtype: int64

# %%
df_Autos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
df_Autos["doors"].replace(np.nan, "four", inplace= True)

# %%
valoresPerdidos=df_Autos.isnull() # buscar nulos
for column in valoresPerdidos.columns.values.tolist():
    print(column)
    print(valoresPerdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    226
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    226
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engine-size
# False    226
# Name: engine-size, dtype: int64
#
# system
# False    226
# ...

# %% [markdown]
# <h3 Style="color:color:##2F4F4F">2.5 Eliminar filas con valores faltantes</h3>

# %%
df_Autos.dropna(subset=["price"], axis= 0, inplace= True)
df_Autos.reset_index(drop= True, inplace=True)

# %%
df_Autos.dropna(subset=["bore"], axis= 0, inplace= True)
df_Autos.reset_index(drop= True, inplace=True)

# %%
df_Autos.dropna(subset=["stroke"], axis= 0, inplace= True)
df_Autos.reset_index(drop= True, inplace=True)

# %%
df_Autos.dropna(subset=["horsepower"], axis= 0, inplace= True)
df_Autos.reset_index(drop= True, inplace=True)

# %%
df_Autos.dropna(subset=["peak"], axis= 0, inplace= True)
df_Autos.reset_index(drop= True, inplace=True)

# %%
df_Autos
# Out:
#      symboling normalized         make    fuel aspiration doors        style  \
# 0            3        122  alfa-romero     gas        std   two  convertible
# 1            3        122  alfa-romero     gas        std   two  convertible
# 2            1        122  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 211          0        122   volkswagen  diesel      turbo  four        sedan
# 212          0        122   volkswagen     gas        std  four        wagon
# 213         -2        103        volvo     gas        std  four        sedan
# 214         -1         74        volvo     gas        std  four        wagon
# 215         -2        103        volvo     gas        std  four        sedan
#
# ...

# %%
valoresPerdidos=df_Autos.isnull()
for column in valoresPerdidos.columns.values.tolist():
    print(column)
    print(valoresPerdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    216
# Name: symboling, dtype: int64
#
# normalized
# False    216
# Name: normalized, dtype: int64
#
# make
# False    216
# Name: make, dtype: int64
#
# fuel
# False    216
# Name: fuel, dtype: int64
#
# aspiration
# False    216
# Name: aspiration, dtype: int64
#
# doors
# False    216
# Name: doors, dtype: int64
#
# style
# False    216
# Name: style, dtype: int64
#
# wheels
# False    216
# Name: wheels, dtype: int64
#
# engine
# False    216
# Name: engine, dtype: int64
#
# base
# False    216
# Name: base, dtype: int64
#
# length
# False    216
# Name: length, dtype: int64
#
# width
# False    216
# Name: width, dtype: int64
#
# heingt
# False    216
# Name: heingt, dtype: int64
#
# curb
# False    216
# Name: curb, dtype: int64
#
# engineType
# False    216
# Name: engineType, dtype: int64
#
# Cylinders
# False    216
# Name: Cylinders, dtype: int64
#
# engine-size
# False    216
# Name: engine-size, dtype: int64
#
# system
# False    216
# ...

# %% [markdown]
# <h2 Style="color:#DC143C">3. Estandarizacion de Datos </h2>
# <p>Que se hace en esta etapa?</p>
#
#
# <ol>
#     <li>Verificar el dominio de las variables y se ajusta, si es necesario </li>
#     <li>Convertir valores en funcion de la interpretacion </li>
#     <li>Normalizar los datos para que sus valores queden entre 0 y 1 </li>
#     <li>Agrupar datos(Binning) </li>
#
# </ol>
#
# <h3 Style="color:color:##2F4F4F">3.1 Verificar el dominio de las variables</h3>

# %%
df_Autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
dfAutos.dtypes # para ver el tipo de la variable float,int64,arreglar los que dicen objet.
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
df_Autos[["normalized", "peak"]]= df_Autos[["normalized", "peak"]].astype("int")
df_Autos[["bore", "stroke","price"]]= df_Autos[["bore", "stroke", "price"]].astype("float")

# %%
df_Autos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower      object
# peak             int32
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h3 Style="color:color:##2F4F4F">3.2 Convertir valores en funcion de su interpretacion </h3>

# %%
df_Autos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City  Higway    price
# ...

# %%
df_Autos["city-L/100KM"]=235/df_Autos["City"]
df_Autos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  system  bore  stroke  compression horsepower  \
# 0    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0        111
# 1    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0        111
# 2    rwd  front  94.5  ...    mpfi  2.68    3.47          9.0        154
# 3    fwd  front  99.8  ...    mpfi  3.19    3.40         10.0        102
# 4    4wd  front  99.4  ...    mpfi  3.19    3.40          8.0        115
#
#    peak  City Higway    price  city-L/100KM
# ...

# %%
df_Autos["Higway-L/100KM"]=235/df_Autos["Higway"]
df_Autos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway    price  city-L/100KM  Higway-L/100KM
# ...

# %% [markdown]
# <h3 Style="color:color:##2F4F4F">3.3 Normalizacion de los Datos</h3>

# %%
df_Autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   symboling       216 non-null    int64
#  1   normalized      216 non-null    int32
#  2   make            216 non-null    object
#  3   fuel            216 non-null    object
#  4   aspiration      216 non-null    object
#  5   doors           216 non-null    object
#  6   style           216 non-null    object
#  7   wheels          216 non-null    object
#  8   engine          216 non-null    object
#  9   base            216 non-null    float64
#  10  length          216 non-null    float64
#  11  width           216 non-null    float64
#  12  heingt          216 non-null    float64
#  13  curb            216 non-null    int64
#  14  engineType      216 non-null    object
#  15  Cylinders       216 non-null    object
#  16  engine-size     216 non-null    int64
# ...

# %%
dfTemp=df_Autos[["length","width","heingt"]]
dfTemp.head(5)
# Out:
#    length  width  heingt
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   171.2   65.5    52.4
# 3   176.6   66.2    54.3
# 4   176.6   66.4    54.3

# %%
df_Autos["length"]=df_Autos["length"]/df_Autos["length"].max()
df_Autos["width"]=df_Autos["width"]/df_Autos["width"].max()
df_Autos["heingt"]=df_Autos["heingt"]/df_Autos["heingt"].max()

# %%
dfTemp=df_Autos[["length","width","heingt"]]
dfTemp.head(5)
# Out:
#      length     width    heingt
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# <h3 Style="color:color:#2F4F4F">3.4Binning</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway    price  city-L/100KM  Higway-L/100KM
# ...

# %%
dfAutos[["horsepower"]]=dfAutos[["horsepower"]].astype("int")
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   symboling       216 non-null    int64
#  1   normalized      216 non-null    int32
#  2   make            216 non-null    object
#  3   fuel            216 non-null    object
#  4   aspiration      216 non-null    object
#  5   doors           216 non-null    object
#  6   style           216 non-null    object
#  7   wheels          216 non-null    object
#  8   engine          216 non-null    object
#  9   base            216 non-null    float64
#  10  length          216 non-null    float64
#  11  width           216 non-null    float64
#  12  heingt          216 non-null    float64
#  13  curb            216 non-null    int64
#  14  engineType      216 non-null    object
#  15  Cylinders       216 non-null    object
#  16  engine-size     216 non-null    int64
# ...

# %%
cat=np.linspace(min(df_Autos["horsepower"]),max(dfAutos["horsepower"]),4)
cat
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
nombres=["bajo", "medio","alto"]
df_Autos["horsepower-bins"]=pd.cut(df_Autos["horsepower"],bins=cat, labels=nombres, include_lowest=True)
df_Autos[["horsepower","horsepower-bins"]].head(5)
# Out:
#    horsepower horsepower-bins
# 0         111            bajo
# 1         111            bajo
# 2         154           medio
# 3         102            bajo
# 4         115            bajo

# %%
df_Autos["horsepower-bins"].value_counts()
# Out:
# bajo     169
# medio     42
# alto       5
# Name: horsepower-bins, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hist(df_Autos["horsepower-bins"])
plt.xlabel("Horsepower")
plt.ylabel("Cantidad Autos")
plt.title("Distribucion Autos segun Caballos de fuerza")
plt.show()

# %% [markdown]
# <h2 Style="color:#6294ED">4. Visualizacion de Datos </h2>
# <p>Que se hace en esta etapa?</p>
#
#
# <ol>
#     <li>Verificar el dominio de las variables y se ajusta, si es necesario </li>
#     <li>Responder las preguntas de Negocio </li>
#     <li>Liberar conocimiento</li>
#     <li>Generar informe al Negocio</li>
#
# </ol>

# %%
gf1= df_Autos.groupby(["horsepower-bins"]).count()
gf1=gf1.iloc[:,:1]
gf1
# Out:
#                  symboling
# horsepower-bins
# bajo                   169
# medio                   42
# alto                     5

# %%
eje_x= ("Bajo","Medio","Alto")
eje_y= gf1["symboling"].tolist()
#creamos la grafica 
plt.bar(eje_x, eje_y)
# Leyenda en el eje y
plt.ylabel("Cantidad de Autos")
#leyenda en el eje x
plt.xlabel("Caballos de Fuerza").set_color("#0000FF")
#Titulo del Grafico
plt.title("Autos agrupados por caballos de fuerza")
plt.figure(figsize=(15,20))
plt.show()

# %%
gf2=df_Autos.groupby(["make"]).count()
gf2=gf2.iloc[:,:1]
#gf2t = gf2.sort_values("symboling")#estas 2 lineas ultimas de codigo ordena por cantidad de menor a mayor en caso de activar
#gf2t
gf2
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   6
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  2
# jaguar                 3
# mazda                 13
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                18
# peugot                11
# plymouth               7
# porsche                4
# saab                   6
# subaru                12
# toyota                46
# volkswagen            24
# volvo                  6

# %%
eje_x = ("alfa-romero","audi","bmw","chevrolet","dodge","honda","isuzu","jaguar","mazda","Mercedez","Mercury","mitsubishi","nissan","peugot","plymouth","porshe","Saab","subaru","Toyota","Volkswagen","Volvo")
eje_y = gf2["symboling"].tolist()
 
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos=np.arange(len(eje_x))



ax.barh(y_pos, eje_y, align ="center", color= "#006400")
ax.set_yticks(y_pos, labels=eje_x)
ax.invert_yaxis()
ax.set_xlabel("performance").set_color("#0000FF")
ax.set_title("Cantidad de vehiculos según fabricante")


plt.show()

# %% [markdown]
# quede 52 min graba

# %%
df_Autos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  stroke  compression  horsepower  peak City Higway  \
# 0    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
# 1    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
#
#      price city-L/100KM  Higway-L/100KM  horsepower-bins
# 0  13495.0    11.190476        8.703704             bajo
# 1  16500.0    11.190476        8.703704             bajo
#
# [2 rows x 29 columns]

# %%
gf3=df_Autos.groupby(["doors"]).count()
gf3=gf3.iloc[:,:1]
gf3
# Out:
#        symboling
# doors
# four         124
# two           92

# %%
etiqueta = "four" , "two"
sizes = gf3["symboling"].tolist()

separacion = (0, 0.1)
figl , axl = plt.subplots()
axl.pie(sizes , explode = separacion, labels=etiqueta, autopct="%1.2f%%", shadow=True, startangle=90)
axl.axis("equal")   
        
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 1:30 quedo el ejercicio

# %%
gf4=df_Autos.groupby(["style"]).count()
gf4=gf4.iloc[:,:1]
gf4
# Out:
#              symboling
# style
# convertible          8
# hardtop             10
# hatchback           70
# sedan              103
# wagon               25

# %%
fig, ax = plt.subplots(figsize=(8,4), subplot_kw=dict(aspect="equal"))
data = gf4['symboling'].tolist()
estilo = ['Convertible', 'Hardtop', 'Hatchback', 'Sedan', 'Wagon']
def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%".format(pct, absolute)
wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))
ax.legend(wedges, estilo,
          title="Estilo",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1.5))
plt.setp(autotexts, size=6, weight="bold")
ax.set_title("Autos segun estilo")
plt.show()

# %%
df_Autos.head(6)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
# 5          2         122         audi  gas        std   two        sedan
#
#   wheels engine  base  ...  stroke  compression  horsepower  peak City Higway  \
# 0    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
# 1    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
# 2    rwd  front  94.5  ...    3.47          9.0         154  5000   19     26
# 3    fwd  front  99.8  ...    3.40         10.0         102  5500   24     30
# ...

# %%
gf5=df_Autos.groupby(["style"]).count()
gf5=gf5.iloc[:,:1]
gf5
# Out:
#              symboling
# style
# convertible          8
# hardtop             10
# hatchback           70
# sedan              103
# wagon               25

# %%
# Colores crear una grafica de anillos
colors = ['#FCF4D9', '#8ED2C9', '#00AAA0', 
          '#FF7A5A', '#FFB85F']
 
# Separaciones
explode = (0.05, 0.05, 0.05, 0.05, 0.05)

# Creacion de grafica circular
plt.pie(data, colors=colors, labels=estilo,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)

# dibujo de circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()

# Esta linea agrega el cirulo blanco sobre la grafica
fig.gca().add_artist(centre_circle)

plt.title('Distribucion de autos segun estilo')

# Displaing Chart
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(df_Autos['price'], df_Autos['city-L/100KM'],s=df_Autos['horsepower'], alpha=0.4)

 

ax.set_xlabel("Precio", fontsize=15)
ax.set_ylabel("Consumo litros gasolina en ciudad", fontsize=15)
ax.set_title('Volume and percent change')

 

ax.grid(True)
fig.tight_layout()

 

plt.show()
