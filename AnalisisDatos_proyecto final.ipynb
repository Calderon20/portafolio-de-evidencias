# %% [markdown]
# <img SRC="IMG1.png" />
#          <center><h1 Style="color:##228B22">Analisis de Datos</h1></center>
#          <center><h2 Style="#228B22">Proyecto Final: Haffeth Calderón Guzmán </h2></center>
#          <center><h5>Universidad Castro Carazo</h5></center>
#          <center><h6>2C- 2022</h6></center>
#          </br>
#          </br>

# %% [markdown]
# <h2 Style="color:#228B22"> El siguiente trabajo consiste en el analisis de datos por medio de python, anaconda y jupyter notebook.
# El siguiente proyecto consiste en aplicar técnicas de análisis de datos con el fin de elaborar una propuesta que ayude a mitigar los distintos procesos que aceleran el cambio climático.</h2>
# </br>
#
# <a href="http://www.sinamecc.go.cr/">Fuente de datos para el analisis</a>

# %% [markdown]
# <img SRC="img04.png"/>

# %% [markdown]
# <h2 Style="color:#008000">1. Carga y estandarizacion de los set de datos</h2>
# <p>Que se hace en esta etapa?</p>
#
#
# <ol>
#     <li>Importar las librerias necesarias</li>
#     <li>Importar el o los set de datos</li>
#     <li>Revisar los encabezados de los dataframes</li>
#
# </ol>
#
# <h3 Style="color:#008000"">1.1 Importar las librerias </h3>

# %%
import pandas as pd              #se usa para el manejo de dataframe.
import numpy as  np              #se usa para el manejo de estructura de datos
import matplotlib.pyplot as plt   # se usa para elmanejo de graficos

# %% [markdown]
# <h3 Style="color:#008000">1.2 Importar el set de datos </h3>

# %%
pd.read_excel("consumoporsector.xlsx")
# Out:
#     Año Residencial Servicios Comercial   Público Transporte  Industria  \
# 0  2010   23,382.00  6,146.00  3,513.00  3,869.00  70,319.00  37,995.00
# 1  2011   22,139.00  6,087.00  3,479.00  3,951.00  72,109.00  36,973.00
# 2  2012   21,586.00  6,206.00  3,636.00  4,230.00  74,111.00  37,740.00
# 3  2013   21,366.00  6,246.00  3,870.00  4,296.00  74,637.00  38,994.00
# 4  2014   20,603.00  6,417.00  3,980.00  4,454.00  76,186.00  39,206.00
# 5  2015   20,791.00  6,671.00  4,114.00  4,575.00  81,526.00  38,368.00
# 6  2016   20,620.00  7,042.00  4,306.00  4,687.00  87,538.00  39,728.00
# 7  2017   20,652.00  7,175.00  4,322.00  4,690.00  89,061.00  40,047.00
# 8  2018   19,481.00  7,303.00  4,464.00  4,803.00  91,231.00  39,262.00
#
#   Agropecuario
# 0     2,854.00
# 1     3,092.00
# 2     3,242.00
# 3     3,273.00
# 4     3,254.00
# 5     3,327.00
# 6     3,584.00
# 7     3,761.00
# 8     3,337.00

# %%
dataframe1=pd.read_excel("consumoporsector.xlsx")

# %%
dataframe1.shape
# Out:
# (9, 8)

# %%
pd.read_excel("consumoportipodetransporte.xlsx")
# Out:
#     Año  Terrestre  Marítimo     Aéreo
# 0  2010  63,360.00      85.0  6,874.00
# 1  2011  64,876.00      84.0  7,149.00
# 2  2012  66,765.00      56.0  7,290.00
# 3  2013  67,772.00      90.0  6,775.00
# 4  2014  69,263.00      78.0  6,845.00
# 5  2015  73,986.00      91.0  7,448.00
# 6  2016  79,120.00      58.0  8,360.00
# 7  2017  80,669.00      65.0  8,327.00
# 8  2018  81,953.00      51.0  9,227.00

# %%
dataframe2=pd.read_excel("consumoportipodetransporte.xlsx")

# %%
dataframe2.shape#tamano data frame 1
# Out:
# (9, 4)

# %%
pd.read_excel("consumoporsectorysubsector.xlsx")
# Out:
#                         Descripción        2010        2011        2012  \
# 0               Consumo final total  152,180.00  150,782.00  154,301.00
# 1         Consumo final (no energ.)    3,065.00    1,802.00    2,480.00
# 2        Consumo final (energético)  149,115.00  148,979.00  151,821.00
# 3                       Residencial   23,382.00   22,139.00   21,586.00
# 4                         1. Urbano   10,514.00   11,513.00   11,950.00
# ..                              ...         ...         ...         ...
# 78                 6.d Enfriamiento         - 0         - 0         - 0
# 79         6.e Generación de fuerza         - 0         - 0         - 0
# 80                        6.f Otros         - 0         - 0         - 0
# 81                     Agropecuario    2,854.00    3,092.00    3,242.00
# 82  Consumo no identificado (otros)      953.00    1,106.00      955.00
#
#           2013        2014        2015        2016        2017        2018
# ...

# %%
dataframe3=pd.read_excel("consumoporsectorysubsector.xlsx")

# %%
dataframe3.shape
# Out:
# (83, 10)

# %%
dataframe3.head(38)
# Out:
#                    Descripción        2010        2011        2012  \
# 0          Consumo final total  152,180.00  150,782.00  154,301.00
# 1    Consumo final (no energ.)    3,065.00    1,802.00    2,480.00
# 2   Consumo final (energético)  149,115.00  148,979.00  151,821.00
# 3                  Residencial   23,382.00   22,139.00   21,586.00
# 4                    1. Urbano   10,514.00   11,513.00   11,950.00
# 5                  1.a Cocción    2,076.00    2,078.00    2,154.00
# 6             1.b Enfriamiento    2,076.00    2,078.00    2,154.00
# 7              1.c Iluminación    2,076.00    2,078.00    2,154.00
# 8      1.d Producción de calor    2,076.00    2,078.00    2,154.00
# 9     1.e Generación de fuerza    2,076.00    2,078.00    2,154.00
# 10                    2. Rural   12,868.00   10,626.00    9,636.00
# 11                 2.a Cocción         - 0         - 0         - 0
# 12            2.b Enfriamiento         - 0         - 0         - 0
# ...

# %%
dataframe3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Descripción  83 non-null     object
#  1   2010         83 non-null     object
#  2   2011         83 non-null     object
#  3   2012         83 non-null     object
#  4   2013         83 non-null     object
#  5   2014         83 non-null     object
#  6   2015         83 non-null     object
#  7   2016         83 non-null     object
#  8   2017         83 non-null     object
#  9   2018         83 non-null     object
# dtypes: object(10)
# memory usage: 6.6+ KB

# %%
dataframe3.head(40)
# Out:
#                                   Descripción        2010        2011  \
# 0                         Consumo final total  152,180.00  150,782.00
# 1                   Consumo final (no energ.)    3,065.00    1,802.00
# 2                  Consumo final (energético)  149,115.00  148,979.00
# 3                                 Residencial   23,382.00   22,139.00
# 4                                   1. Urbano   10,514.00   11,513.00
# 5                                 1.a Cocción    2,076.00    2,078.00
# 6                            1.b Enfriamiento    2,076.00    2,078.00
# 7                             1.c Iluminación    2,076.00    2,078.00
# 8                     1.d Producción de calor    2,076.00    2,078.00
# 9                    1.e Generación de fuerza    2,076.00    2,078.00
# 10                                   2. Rural   12,868.00   10,626.00
# 11                                2.a Cocción         - 0         - 0
# ...

# %% [markdown]
# <h2 Style="color:#6294ED"> 4. Visualizacion de Datos </h2>
# <p>Que se hace en esta etapa?</p>
#
#
# <ol>
#     <li>Verificar el dominio de las variables y se ajusta, si es necesario </li>
#     <li>Responder las preguntas de Negocio </li>
#     <li>Liberar conocimiento</li>
#     <li>Generar informe al Negocio</li>
#
# </ol>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
pd.read_excel("consumoporsector.xlsx")
# Out:
#     Año Residencial Servicios Comercial   Público Transporte  Industria  \
# 0  2010   23,382.00  6,146.00  3,513.00  3,869.00  70,319.00  37,995.00
# 1  2011   22,139.00  6,087.00  3,479.00  3,951.00  72,109.00  36,973.00
# 2  2012   21,586.00  6,206.00  3,636.00  4,230.00  74,111.00  37,740.00
# 3  2013   21,366.00  6,246.00  3,870.00  4,296.00  74,637.00  38,994.00
# 4  2014   20,603.00  6,417.00  3,980.00  4,454.00  76,186.00  39,206.00
# 5  2015   20,791.00  6,671.00  4,114.00  4,575.00  81,526.00  38,368.00
# 6  2016   20,620.00  7,042.00  4,306.00  4,687.00  87,538.00  39,728.00
# 7  2017   20,652.00  7,175.00  4,322.00  4,690.00  89,061.00  40,047.00
# 8  2018   19,481.00  7,303.00  4,464.00  4,803.00  91,231.00  39,262.00
#
#   Agropecuario
# 0     2,854.00
# 1     3,092.00
# 2     3,242.00
# 3     3,273.00
# 4     3,254.00
# 5     3,327.00
# 6     3,584.00
# 7     3,761.00
# 8     3,337.00

# %%
plt.figure(figsize=(14,5))
#Sector Residencial
x=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y=[23382, 22139, 21586, 21366, 20603, 20791, 20620, 20652, 19481]
#Sector servicios 
x2=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y2=[6146, 6087, 6206, 6246, 6417, 6671, 7042, 7175, 7303]
#Sector comercial
x3=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y3=[3513,3479,3636,3870,3980,4114,4306,4322,4464]
#Sector Publico
x4=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y4=[3869,3951,4230,4296,4454,4575,4687,4690,4803]
#Sector Transporte
x5=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y5=[70319,72109,74111,74637,76186,81526,87538,89061,91231]
# Sector Industria
x6=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y6=[37995,36973,37740,38994,39206,38368,39728,40047,39262]
# Sector Agropecuario
x7=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y7=[2854,3092,3242,3273,3254,3327,3584,3761,3337]
plt.plot(x, y, marker="o", linestyle="--", color="r",label="Residencial")
plt.plot(x2, y2, marker="o", linestyle="--", color="g",label="Servicios")
plt.plot(x3, y3, marker="o", linestyle="--", color="y",label="Comercial")
plt.plot(x4, y4, marker="o", linestyle="--", color="m",label="Publico")
plt.plot(x5, y5, marker="o", linestyle="--", color="b",label="Transporte")
plt.plot(x6, y6, marker="o", linestyle="--", color="#7FFF00",label="Industria")
plt.plot(x7, y7, marker="o", linestyle="--", color="#000000",label="Agropecuario") 
plt.xlabel("Años")
plt.ylabel("Consumo")
plt.title("Consumo por sector en el periodo 2010-2018")
plt.legend()

plt.show()

# %%
dataframe1.tail(1)
# Out:
#     Año Residencial Servicios Comercial   Público Transporte  Industria  \
# 8  2018   19,481.00  7,303.00  4,464.00  4,803.00  91,231.00  39,262.00
#
#   Agropecuario
# 8     3,337.00

# %%
plt.figure(figsize=(12,4))

x=["Residencial","Servicios","Comercial","Publico", "Transporte","Industria","Agropecuario"]
y=[19481, 7303, 4464, 4803, 91231, 39262 , 3337]
plt.bar(x, y)
plt.title("Consumo por sector en el año 2018")
plt.yticks([0,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,65000,70000,75000,80000])
plt.show()

# %%
dataframe1.max()
# Out:
# Año                  2018
# Residencial     23,382.00
# Servicios        7,303.00
# Comercial        4,464.00
# Público          4,803.00
# Transporte      91,231.00
# Industria       40,047.00
# Agropecuario     3,761.00
# dtype: object

# %%
dataframe2.tail(1)
# Out:
#     Año  Terrestre  Marítimo     Aéreo
# 8  2018  81,953.00      51.0  9,227.00

# %%
plt.figure(figsize=(12,4))

x=["Terrestre","Maritimo","Aéreo"]
y=[81953, 51,9227]
plt.bar(x, y)
plt.title("Consumo por tipo de transporte")

plt.show()

# %%
pd.read_excel("consumoportipodetransporte.xlsx")
# Out:
#     Año  Terrestre  Marítimo     Aéreo
# 0  2010  63,360.00      85.0  6,874.00
# 1  2011  64,876.00      84.0  7,149.00
# 2  2012  66,765.00      56.0  7,290.00
# 3  2013  67,772.00      90.0  6,775.00
# 4  2014  69,263.00      78.0  6,845.00
# 5  2015  73,986.00      91.0  7,448.00
# 6  2016  79,120.00      58.0  8,360.00
# 7  2017  80,669.00      65.0  8,327.00
# 8  2018  81,953.00      51.0  9,227.00

# %%
plt.figure(figsize=(14,5))
#Transporte Terrestre
x=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y=[63360, 64876, 66765, 67772, 69263, 73986, 79120, 80669, 81953]
#Transporte Maritimo 
x2=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y2=[85, 84, 56, 90, 78, 91, 58, 65, 51]
#Trasnporte aereo
x3=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y3=[6874,7149,7290,6775,6845,7448,8360,8327,9227]

plt.plot(x, y, marker="o", linestyle="--", color="r",label="Transporte terrestre")
plt.plot(x2, y2, marker="o", linestyle="--", color="g",label="Transporte Maritimo")
plt.plot(x3, y3, marker="o", linestyle="--", color="y",label="Transporte aereo")
 
plt.xlabel("Años")
plt.ylabel("Consumo por transporte(Terrestre, Maritimo , aereo)")
plt.title("Consumo por sector en el periodo 2010-2018")
plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,4))

x=["1.Privado","2.Público","3.Carga","4.Equipo Especial","5.Otros","6.Ferrocarril"]
y=[41241,8124,30007,2487,38,56]
plt.bar(x, y)
plt.title("Consumo por tipo de transporte terrestre")

plt.show()

# %%
dataframe2.max()
# Out:
# Año               2018
# Terrestre    81,953.00
# Marítimo          91.0
# Aéreo         9,227.00
# dtype: object

# %%
dataframe2.min()
# Out:
# Año               2010
# Terrestre    63,360.00
# Marítimo          51.0
# Aéreo         6,775.00
# dtype: object

# %%
dftem=dataframe3.iloc[19:38,0:10]

# %%
dftem.head(19)
# Out:
#               Descripción       2010       2011       2012       2013  \
# 19             Transporte  70,319.00  72,109.00  74,111.00  74,637.00
# 20              Terrestre  63,360.00  64,876.00  66,765.00  67,772.00
# 21             1. Privado  29,474.00  31,122.00  32,601.00  33,280.00
# 22        1.a Automóviles  20,541.00  19,422.00  19,899.00  19,828.00
# 23               1.b Jeep   4,599.00   7,702.00   8,615.00   9,363.00
# 24  1.c Microbus familiar   1,342.00   1,226.00   1,221.00   1,202.00
# 25              1.d Motos   2,992.00   2,773.00   2,866.00   2,886.00
# 26             2. Público   7,415.00   6,768.00   6,918.00   7,051.00
# 27           2.a Microbus   1,385.00   1,913.00   2,036.00   2,134.00
# 28            2.b Autobus   4,157.00   3,416.00   3,494.00   3,607.00
# 29              2.c Taxis   1,873.00   1,438.00   1,388.00   1,310.00
# 30               3. Carga  21,917.00  24,174.00  24,752.00  25,311.00
# ...

# %%
plt.figure(figsize=(12,4))

x=["1.Privado","2.Público","3.Carga","4.Equipo Especial","5.Otros","6.Ferrocarril"]
y=[41241,8124,30007,2487,38,56]
plt.bar(x, y)
plt.title("Consumo por tipo de transporte terrestre")

plt.show()

# %%
dftem=dataframe3.iloc[19:38,0:10]

# %%
dftem.head(19)
# Out:
#               Descripción       2010       2011       2012       2013  \
# 19             Transporte  70,319.00  72,109.00  74,111.00  74,637.00
# 20              Terrestre  63,360.00  64,876.00  66,765.00  67,772.00
# 21             1. Privado  29,474.00  31,122.00  32,601.00  33,280.00
# 22        1.a Automóviles  20,541.00  19,422.00  19,899.00  19,828.00
# 23               1.b Jeep   4,599.00   7,702.00   8,615.00   9,363.00
# 24  1.c Microbus familiar   1,342.00   1,226.00   1,221.00   1,202.00
# 25              1.d Motos   2,992.00   2,773.00   2,866.00   2,886.00
# 26             2. Público   7,415.00   6,768.00   6,918.00   7,051.00
# 27           2.a Microbus   1,385.00   1,913.00   2,036.00   2,134.00
# 28            2.b Autobus   4,157.00   3,416.00   3,494.00   3,607.00
# 29              2.c Taxis   1,873.00   1,438.00   1,388.00   1,310.00
# 30               3. Carga  21,917.00  24,174.00  24,752.00  25,311.00
# ...

# %%
plt.figure(figsize=(14,5))
#Transporte terrestre privado
x=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y=[29474,31122, 32601,33280,34096, 36899,39762,40694,41241]
##Transporte terrestre publico
x2=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y2=[7415, 6768, 6918,7051,7319,7630, 8015, 8017, 8124]
###Transporte carga
x3=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y3=[21917,24174,24752,25311,25679,27149,28857,29428,30007]
###Transporte terrestre Equipo especial
x4=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y4=[3878,2562,2321,2038,2077,2213,2384,2431,2487]
###Transporte terrestre otros
x5=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y5=[630,200,116,25,27,31,36,37,38]
###Transporte terrestre ferrocarril
x6=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y6=[46,51,57,67,64,64,64,62,56]

plt.plot(x, y, marker="o", linestyle="--", color="r",label="Privado")
plt.plot(x2, y2, marker="o", linestyle="--", color="g",label="Publico")
plt.plot(x3, y3, marker="o", linestyle="--", color="y",label="Carga")
plt.plot(x4, y4, marker="o", linestyle="--", color="m",label="Equipo especial")
plt.plot(x5, y5, marker="o", linestyle="--", color="b",label="otros transportes terrestres")
plt.plot(x6, y6, marker="o", linestyle="--", color="#7FFF00",label="Ferrocarril")
 
plt.xlabel("Años")
plt.ylabel("Consumo")
plt.title("Consumo por transporte terrestre en el periodo 2010-2018")
plt.legend()

plt.show()

# %%
plt.figure(figsize=(18,6))

x=["Automoviles","Jeep","Microbus Familiar","Motos","Microbus","Autobus", "taxis","carga liviana", "carga pesada", "equipo especial","otros"," ferrocarril"]
y=[24251,11778,1433,3778,2513,3968,1643,13914,16093,2487,38,56]
plt.bar(x, y)
plt.title("Consumo por tipo de transporte terrestre")

plt.show()

# %% [markdown]
# <img SRC="IMG1.png" />
#          <center><h1 Style="color:##228B22">Conclusiones</h1></center>
#          <center><h2 Style="#228B22">Proyecto Final: Haffeth Calderón Guzmán </h2></center>
#          <center><h5>Universidad Castro Carazo</h5></center>
#          <center><h6>2C- 2022</h6></center>
#          </br>
#          </br>
# <left><h1 Style="color:##228B22">Se carga 3 sets de datos sobre el consumo de los distintos sectores economicos, demostrandose que el sector transporte es el que más consumo tiene en la economia costarricense.
# Del sector transporte se logra demostrar según los datos que en el sector transporte, el transporte terrestre tiene el mayor peso del consumo energetico.
# A su vez de ese sector terrestre se extrae la información de que el sector privado tiene el mayor peso, seguidamente del sector de Carga.
# Por último se concluye que el ferrorrocarril su consumo es el más bajo y que los automoviles junto la carga pesada son medios de transportes altamente contaminantes.</h1></left>

# %% [markdown]
# <img SRC="02.jpg" />
#          <center><h1 Style="color:##228B22">Recomendaciones</h1></center>
#          <center><h2 Style="#228B22">Proyecto Final: Haffeth Calderón Guzmán </h2></center>
#          <center><h5>Universidad Castro Carazo</h5></center>
#          <center><h6>2C- 2022</h6></center>
#          </br>
#          </br>

# %% [markdown]
#  <right><h1 Style="color:##228B22">Se recomienda al gobierno de Costa Rica invertir en infraestructura que habilite el uso de trenes modernos a lo largo y ancho del país tanto para carga como para el transporte de pasajeros </h1></right>
